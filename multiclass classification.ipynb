# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Dry_Bean_Dataset.xlsx')

# %%
df.head(10)
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
# 5  30279    634.927       212.560556       181.510182      1.171067
# 6  30477    670.033       211.050155       184.039050      1.146768
# 7  30519    629.727       212.996755       182.737204      1.165591
# 8  30685    635.681       213.534145       183.157146      1.165852
# 9  30834    631.934       217.227813       180.897469      1.200834
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
# 5      0.520401       30600     196.347702  0.775688  0.989510   0.943852
# 6      0.489478       30970     196.988633  0.762402  0.984081   0.853080
# 7      0.513760       30847     197.124320  0.770682  0.989367   0.967109
# 8      0.514081       31044     197.659696  0.771561  0.988436   0.954240
# 9      0.553642       31120     198.139012  0.783683  0.990810   0.970278
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER
# 5     0.923726      0.007020      0.003153      0.853270      0.999236  SEKER
# 6     0.933374      0.006925      0.003242      0.871186      0.999049  SEKER
# 7     0.925480      0.006979      0.003158      0.856514      0.998345  SEKER
# 8     0.925658      0.006959      0.003152      0.856844      0.998953  SEKER
# 9     0.912125      0.007045      0.003008      0.831973      0.999061  SEKER

# %%
df['Class'].value_counts()
# Out:
# Class
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1928
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
df.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# min        1.024868      0.218951   20684.000000     161.243764      0.555315
# 25%        1.432307      0.715928   36714.500000     215.068003      0.718634
# 50%        1.551124      0.764441   45178.000000     238.438026      0.759859
# 75%        1.707109      0.810466   62294.000000     279.446467      0.786851
# max        2.430306      0.911423  263261.000000     569.374358      0.866195
#
#            Solidity     roundness   Compactness  ShapeFactor1  ShapeFactor2  \
# count  13611.000000  13611.000000  13611.000000  13611.000000  13611.000000
# mean       0.987143      0.873282      0.799864      0.006564      0.001716
# std        0.004660      0.059520      0.061713      0.001128      0.000596
# min        0.919246      0.489618      0.640577      0.002778      0.000564
# 25%        0.985670      0.832096      0.762469      0.005900      0.001154
# 50%        0.988283      0.883157      0.801277      0.006645      0.001694
# 75%        0.990013      0.916869      0.834270      0.007271      0.002170
# max        0.994677      0.990685      0.987303      0.010451      0.003665
#
#        ShapeFactor3  ShapeFactor4
# count  13611.000000  13611.000000
# mean       0.643590      0.995063
# std        0.098996      0.004366
# min        0.410339      0.947687
# 25%        0.581359      0.993703
# 50%        0.642044      0.996386
# 75%        0.696006      0.997883
# max        0.974767      0.999733

# %%
df.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
x = df.drop('Class',axis=1)
y = df['Class']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
y = to_categorical(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(
    x,
    y,
    test_size = 0.2,
    random_state = 42
)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = Sequential()
model.add(Dense(128,activation = 'relu',input_shape=(16,)))
model.add(Dense(64,activation = 'relu'))
model.add(Dense(32,activation = 'relu'))
model.add(Dense(7,activation = 'softmax'))
# Out:
# C:\Users\Lenovo\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam',loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs = 50,batch_size = 32,validation_split = 0.2)
# Out:
# Epoch 1/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9458 - loss: 0.1418 - val_accuracy: 0.9317 - val_loss: 0.2233
# Epoch 2/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9461 - loss: 0.1403 - val_accuracy: 0.9349 - val_loss: 0.2099
# Epoch 3/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9444 - loss: 0.1409 - val_accuracy: 0.9359 - val_loss: 0.2089
# Epoch 4/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9436 - loss: 0.1425 - val_accuracy: 0.9340 - val_loss: 0.2151
# Epoch 5/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9427 - loss: 0.1449 - val_accuracy: 0.9335 - val_loss: 0.2101
# Epoch 6/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9446 - loss: 0.1381 - val_accuracy: 0.9368 - val_loss: 0.2143
# Epoch 7/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9457 - loss: 0.1368 - val_accuracy: 0.9322 - val_loss: 0.2145
# Epoch 8/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9446 - loss: 0.1371 - val_accuracy: 0.9349 - val_loss: 0.2092
# Epoch 9/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9443 - loss: 0.1366 - val_accuracy: 0.9331 - val_loss: 0.2228
# Epoch 10/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9468 - loss: 0.1375 - val_accuracy: 0.9322 - val_loss: 0.2143
# Epoch 11/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9482 - loss: 0.1345 - val_accuracy: 0.9312 - val_loss: 0.2184
# Epoch 12/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9487 - loss: 0.1341 - val_accuracy: 0.9266 - val_loss: 0.2362
# Epoch 13/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9455 - loss: 0.1366 - val_accuracy: 0.9331 - val_loss: 0.2223
# Epoch 14/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9440 - loss: 0.1370 - val_accuracy: 0.9331 - val_loss: 0.2174
# Epoch 15/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9463 - loss: 0.1327 - val_accuracy: 0.9335 - val_loss: 0.2250
# Epoch 16/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9505 - loss: 0.1301 - val_accuracy: 0.9252 - val_loss: 0.2431
# Epoch 17/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9498 - loss: 0.1305 - val_accuracy: 0.9354 - val_loss: 0.2269
# Epoch 18/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9477 - loss: 0.1298 - val_accuracy: 0.9280 - val_loss: 0.2283
# Epoch 19/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9483 - loss: 0.1306 - val_accuracy: 0.9289 - val_loss: 0.2344
# Epoch 20/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9491 - loss: 0.1275 - val_accuracy: 0.9248 - val_loss: 0.2460
# Epoch 21/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9482 - loss: 0.1301 - val_accuracy: 0.9294 - val_loss: 0.2280
# Epoch 22/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9505 - loss: 0.1282 - val_accuracy: 0.9382 - val_loss: 0.2225
# Epoch 23/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9498 - loss: 0.1241 - val_accuracy: 0.9299 - val_loss: 0.2340
# Epoch 24/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9504 - loss: 0.1264 - val_accuracy: 0.9312 - val_loss: 0.2344
# Epoch 25/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9489 - loss: 0.1271 - val_accuracy: 0.9294 - val_loss: 0.2397
# Epoch 26/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9511 - loss: 0.1238 - val_accuracy: 0.9340 - val_loss: 0.2281
# Epoch 27/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9498 - loss: 0.1231 - val_accuracy: 0.9252 - val_loss: 0.2444
# Epoch 28/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9515 - loss: 0.1208 - val_accuracy: 0.9280 - val_loss: 0.2458
# Epoch 29/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9528 - loss: 0.1195 - val_accuracy: 0.9280 - val_loss: 0.2374
# Epoch 30/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9503 - loss: 0.1246 - val_accuracy: 0.9289 - val_loss: 0.2426
# Epoch 31/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9507 - loss: 0.1217 - val_accuracy: 0.9322 - val_loss: 0.2411
# Epoch 32/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9499 - loss: 0.1222 - val_accuracy: 0.9299 - val_loss: 0.2373
# Epoch 33/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9543 - loss: 0.1176 - val_accuracy: 0.9289 - val_loss: 0.2545
# Epoch 34/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9519 - loss: 0.1185 - val_accuracy: 0.9294 - val_loss: 0.2453
# Epoch 35/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9528 - loss: 0.1194 - val_accuracy: 0.9252 - val_loss: 0.2523
# Epoch 36/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9535 - loss: 0.1209 - val_accuracy: 0.9322 - val_loss: 0.2512
# Epoch 37/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9541 - loss: 0.1161 - val_accuracy: 0.9317 - val_loss: 0.2593
# Epoch 38/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9547 - loss: 0.1176 - val_accuracy: 0.9289 - val_loss: 0.2498
# Epoch 39/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9532 - loss: 0.1166 - val_accuracy: 0.9363 - val_loss: 0.2419
# Epoch 40/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9560 - loss: 0.1132 - val_accuracy: 0.9340 - val_loss: 0.2424
# Epoch 41/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9550 - loss: 0.1132 - val_accuracy: 0.9308 - val_loss: 0.2553
# Epoch 42/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9551 - loss: 0.1141 - val_accuracy: 0.9317 - val_loss: 0.2657
# Epoch 43/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9566 - loss: 0.1120 - val_accuracy: 0.9312 - val_loss: 0.2674
# Epoch 44/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9557 - loss: 0.1106 - val_accuracy: 0.9262 - val_loss: 0.2753
# Epoch 45/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9559 - loss: 0.1089 - val_accuracy: 0.9266 - val_loss: 0.2801
# Epoch 46/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9551 - loss: 0.1136 - val_accuracy: 0.9317 - val_loss: 0.2618
# Epoch 47/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9555 - loss: 0.1099 - val_accuracy: 0.9294 - val_loss: 0.2616
# Epoch 48/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9559 - loss: 0.1086 - val_accuracy: 0.9312 - val_loss: 0.2716
# Epoch 49/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9571 - loss: 0.1100 - val_accuracy: 0.9299 - val_loss: 0.2637
# Epoch 50/50
# 271/271 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9556 - loss: 0.1133 - val_accuracy: 0.9303 - val_loss: 0.2701

# %%
y_pred = model.predict(x_test)
# Out:
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
y_pred = np.argmax(y_pred,axis = 1)
y_true = np.argmax(y_test,axis = 1)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print(accuracy_score(y_true,y_pred))
# Out:
# 0.9213732004429679

# %%
print(classification_report(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91       259
#            1       1.00      1.00      1.00       114
#            2       0.96      0.90      0.93       305
#            3       0.94      0.90      0.92       707
#            4       0.95      0.95      0.95       376
#            5       0.94      0.95      0.94       414
#            6       0.85      0.90      0.87       534
#
#     accuracy                           0.92      2709
#    macro avg       0.93      0.93      0.93      2709
# weighted avg       0.92      0.92      0.92      2709

# %%
print(confusion_matrix(y_true,y_pred))
# Out:
# [[242   0   8   0   1   2   6]
#  [  0 114   0   0   0   0   0]
#  [ 23   0 275   0   2   3   2]
#  [  0   0   0 638   1  14  54]
#  [  3   0   4   3 356   0  10]
#  [  3   0   0   8   0 392  11]
#  [  3   0   0  31  14   7 479]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
cm = confusion_matrix(y_true,y_pred)
plt.figure(figsize =(15,9))
sns.heatmap(cm,annot=True,fmt='d')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train','Validation'])
plt.show()

# %%
model.save('drybean_ann.keras')
